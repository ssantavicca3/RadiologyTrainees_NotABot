# %% [markdown]
# # Goal with this is to nail down the part of the scraper that actually retreives and parses each profile's webpage.
#
# Only example scraping health.usnews.com (granted, I didn't search too much): https://medium.com/analytics-vidhya/web-scraping-best-childrens-hospitals-for-cancer-5574db6d4090
#
# HTML formatter to help with HTML parsing: https://webformatter.com/html

# %%
# Once I'm at the radiologist's webpage
from bs4 import BeautifulSoup
import requests

import json
import pandas as pd

import pprint

from urllib.request import Request, urlopen

# %% [markdown]
# # Take Aways
# 1. Ultimately I think I need to find a way to just request/pull the specific info from a page rather than the whole thing.
#     - I think I can do this with py.scrapy
# 2. I should also look into cycling (a) IP address and (b) headers.

# %%
url = 'https://health.usnews.com/doctors/richard-duszak-130940'
prefix = 'https://health.usnews.com/'
user_agent = {'User-agent' : 'Mozilla/5.0'}
page = requests.get(url, headers=user_agent)
soup = BeautifulSoup(page.text, "html.parser")

# %%
# Narrow down the HTML to the section I want using "id"
results = soup.find(id="experience")
print(results.prettify())

#NB could directly use:
# ed_ex_elements = soup.findAll("div", {"class": "EducationAndExperience__Item-dbww3o-0 eUTnkN"})
# Out:
# <section class="content__Section-sc-1g5jtse-0 iBkvsh" id="experience">
#  <h2 class="Heading__HeadingStyled-sc-1w5xk2o-0-h2 jWflL Heading-sc-1w5xk2o-1 cRrhAX" size="4" spacing="4">
#   Education &amp; Experience
#  </h2>
#  <div class="mb5">
#   <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 ipbGql Heading-sc-1w5xk2o-1 cRrhAX border-bottom pb1" size="2" spacing="3">
#    Medical School &amp; Residency
#   </h3>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     University of Pennsylvania Health System
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Fellowship
#     <span class="Span-sc-19wk4id-0 kukjnS" size="5">
#      ,
#      <!-- -->
#      Vascular and Interventional Radiology
#     </span>
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     Duke University Hospital
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Residency
#     <span class="Span-sc-19wk4id-0 kukjnS" size="5">
#      ,
#      <!-- -->
#      Radiology
#     </span>
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     York Hospital
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Internship
#     <span class="Span-sc-19wk4id-0 kukjnS" size="5">
#      ,
#      <!-- -->
#      Transitional Year
#     </span>
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     Pennsylvania State University College of Medicine
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Medical School
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 bMIddY" spacing="0">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Other Training
#     <span class="Span-sc-19wk4id-0 kukjnS" size="5">
#      ,
#      <!-- -->
#      Biology
#     </span>
#    </p>
#   </div>
#  </div>
#  <div class="mb5">
#   <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 ipbGql Heading-sc-1w5xk2o-1 cRrhAX border-bottom pb1" size="2" spacing="3">
#    Certifications &amp; Licensure
#   </h3>
#   <div class="mb4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     American Board of Radiology
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Certified in
#     <!-- -->
#     Interventional Radiology and Diagnostic Radiology
#    </p>
#   </div>
#   <div class="mb4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     National Board of Physicians and Surgeons
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Certified in
#     <!-- -->
#     Diagnostic Radiology
#    </p>
#   </div>
#   <div class="mb4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     National Board of Physicians and Surgeons
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Certified in
#     <!-- -->
#     Vascular and Interventional Radiology
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     NC State Medical License
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Active through
#     <!-- -->
#     1998
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     PA State Medical License
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Active through
#     <!-- -->
#     2014
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     MS State Medical License
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Active through
#     <!-- -->
#     2015
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     TN State Medical License
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Active through
#     <!-- -->
#     2015
#    </p>
#   </div>
#   <div class="EducationAndExperience__Item-dbww3o-0 bMIddY" spacing="0">
#    <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#     GA State Medical License
#    </p>
#    <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#     Active through
#     <!-- -->
#     2022
#    </p>
#   </div>
#  </div>
#  <div class="mb5">
#   <div class="flex-column">
#    <span class="Span-sc-19wk4id-0 generic-toggler__Toggler-v0jryl-0 blHoZQ gzQShs EducationAndExperience__CustomToggler-dbww3o-1 XqWRJ" size="3" tabindex="0">
#     <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 gGkki Heading-sc-1w5xk2o-1 EducationAndExperience__CustomHeading-dbww3o-2 cRrhAX fXoLCi" size="2" spacing="0">
#      Awards, Honors &amp; Recognitions
#     </h3>
#     <svg class="Icon-sc-9wq8ul-0 generic-toggler__Chevron-v0jryl-1 hiHdJZ ldwRQL" height="1rem" role="img" width="1rem">
#      <use filter="0" xlink:href="#chevron">
#      </use>
#     </svg>
#    </span>
#    <div class="use-hidden-content__HiddenContent-sc-1i61n0d-0 kGUuPQ" spacing="0">
#     <div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        SIR Fellow
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Outstanding Faculty Mentor Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2015
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Most Influential Radiology Researcher
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2014
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Outstanding Reviewer Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2014
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Volunteer Service Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2014
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        William T. Thorwarth, Jr. Award for Excellence in Economics and Health Policy
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2013
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Best Doctors in Memphis
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2011
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Best Doctors in Memphis
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2012
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Featured Alumnus
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2010
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Fellow, Radiology Business Management Association
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2010
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Fellow (RBMA)
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2010
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Fellow, American College of Radiology
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2007
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Fellow (ACR)
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2007
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Exceptional Manuscript Reviewer Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2005
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Fellow, Society of Interventional Radiology
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2004
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Best Doctors in America
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2001
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Calhoun Award for Outstanding Contributions to Radiology Management
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2000
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Editor’s Recognition Award, with Special Distinction
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1999
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Editor’s Recognition Award, with Special Distinction
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 2000
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Distinguished Faculty Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1999
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Distinguished Reviewer Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1998
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Residents Annual Award for Excellence in Teaching
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1996
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Andrew E. Yeates Memorial Award for Excellence in Neuroradiology
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1993
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Sylvia and Gilbert Nurick Medical Achievement Award for Academic Excellence and Outstanding Contributions to the College Community
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1989
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        The Edward C. Hammond Memorial Scholarship for Academic Excellence
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1987
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Alpha Omega Alpha Honor Medical Society
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1987
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Biology Department Outstanding Graduate Award
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1985
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        University Scholarship
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#         , 1981
#        </span>
#       </p>
#      </div>
#      <div class="EducationAndExperience__Item-dbww3o-0 bMIddY" spacing="0">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Annual AuntMinnie.com  Minnies Awards for Excellence in Radiology
#        <span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">
#        </span>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="mb5">
#   <div class="flex-column">
#    <span class="Span-sc-19wk4id-0 generic-toggler__Toggler-v0jryl-0 blHoZQ gzQShs EducationAndExperience__CustomToggler-dbww3o-1 XqWRJ" size="3" tabindex="0">
#     <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 gGkki Heading-sc-1w5xk2o-1 EducationAndExperience__CustomHeading-dbww3o-2 cRrhAX fXoLCi" size="2" spacing="0">
#      Publications
#     </h3>
#     <svg class="Icon-sc-9wq8ul-0 generic-toggler__Chevron-v0jryl-1 hiHdJZ ldwRQL" height="1rem" role="img" width="1rem">
#      <use filter="0" xlink:href="#chevron">
#      </use>
#     </svg>
#    </span>
#    <div class="use-hidden-content__HiddenContent-sc-1i61n0d-0 kGUuPQ" spacing="0">
#     <div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Downstream Imaging Utilization After Emergency Department Ultrasound Interpreted by Radiologists Versus Nonradiologists: A Medicare Claims–Based Study
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Richard Duszak, Richard Duszak, Andrew B. Rosenkrantz, Andrew B. Rosenkrantz
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Implementation of a Novel Surveillance Template for Head and Neck Cancer: Neck Imaging Reporting and Data System (NI-RADS).
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Aiken, A. H.,Farley, A.,Baugnon, K. L.,Corey, A.,El-Deiry, M.,Duszak, R.,Beitler, J.,Hudgins, P. A.
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Emergency Department Imaging Superusers
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Adam Prater, Richard Duszak, Kush Singh
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Actionable reporting.
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Boland, G. W.,Enzmann, D. R.,Duszak, R.
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Characteristics of MR Neuroimaging Services Billed by Radiologists Versus Nonradiologists
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        R Jr Duszak, P P Harkey, P E Sharp
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Use and Cost of Actinic Keratosis Destruction in the Medicare Part B Fee-for-Service Population, 2007 to 2015
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Robert A Swerlick, Howa Yeung, Richard Jr Duszak, Suephy C Chen
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Recent Trends in Adherence to Continuous Screening for  Breast Cancer among Medicare Beneficiaries
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Jiang M, Hughes DR, Appleton CM, McGinty G
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Expanding Roles of Nurse Practitioners and Physicians Assistants as Providers of Non-Vascular Radiology Procedures
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Walls DG, Wang JM, Hemingway J, Hughes DR, Small WC, Bowen MA
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Traditional Text-Only vs Multimedia Enhanced Radiology Reporting: Referring Physician's Perception of Value
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Sadigh G, Hertweck T, Kao C, Wood P, Hughes DR, Henry TS
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Screening Mammography Rates in the Medicare Population Before and After the 2009 US Preventive Services Task Force Guideline Change: An Interrupted Time Series Analysis
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Jiang M, Hughes DR
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        State Variation in Medical Imaging: Despite Great Variation, the Medicare Spending Decline Continues
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Rosenkrantz AB, Hughes DR
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Percutaneous Hepatic and Renal Biopsy Procedures: An 18 Year Analysis of Changing Utilization, Specialty Roles, and Sites of Service
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Angel W, Hawkins CM, Wang JM, Hughes DR
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Diagnostic Radiology Resident and Fellow Workloads: A 12 Year Longitudinal Trend Analysis Using National Medicare Aggregate Claims Data
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Chokshi F, Hughes DR, Wang JM, Mullins ME, Hawkins CM
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Physician Rating Websites: Do Radiologists Have an Online Presence?
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Gilbert AK, Hawkins CM, Hughes DR, Patel K, Gogia N, Sekhar A
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Can Patients Comprehend the Educational Materials that Hospitals Provide About Common Interventional Radiology Procedures?
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Sadigh G, Hawkins CM, O’Keefe JJ, Khan R
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Regional Variation in Medicare Payments for Medical Imaging: Radiologists vs Non-Radiologists
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Andrew B. Rosenkrantz, Richard Duszak, Lauren Parks Golding, Gregory N. Nicola
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Dense Breast Notification Laws: Impact on Downstream Imaging After Screening Mammography.
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#        Michal Horný, Alan B. Cohen, Richard Duszak, Cindy L. Christiansen, Michael Shwartz, James F. Burgess
#       </p>
#      </div>
# ...
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Central Venous Access Devices: Management of Catheter Complications
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Venous Thromboembolic Disease: An Interventional Radiologist’s Perspective
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Coding and Billing for Interventional Radiology: Get What You Deserve, And Stay Out of Trouble
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Central Venous Challenges: Catheter Salvage and Vein Preservation
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Interventional Radiology: A Prototype of Minimally Invasive Therapy
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Venous Thromboembolic Disease: Endovascular Intervention
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Central Venous Access Devices: Management of Catheter Related Problems
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Central Venous Occlusive Disease
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Central Venous Access Device Problems
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Venous Thromboembolic Disease: Diagnostic Imaging
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Complicated Venous Thromboembolic Disease
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Endovascular Treatment of Venous Disease
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Venous Thromboembolic Disease: Diagnostic Strategies and Endovascular Intervention
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Venous Thromboembolic Disease
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Imaging of Stroke
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Abdominal Interventional Radiology
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Radiographic Evaluation of Child Abuse
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#      <div class="mb4">
#       <p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">
#        Health Care Reform Update
#       </p>
#       <p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div>
#   <div class="Ad__Container-sc-1ah7c5n-0 dBtSv RectToLeaderboardAd__CustomLeaderboardAd-sc-18ls5m1-0 CoqsW mt6" spacing="6">
#    <div class="ad" data-ad-props='{"type":"lb","dimensions":"728x90","separator":"_","lazy":false,"borderTop":true,"borderBottom":true,"borderColor":"#D3D7DC","insetSpacing":1,"autoRefresh":false,"spacing":6,"breakpoint":"extraLarge","className":"RectToLeaderboardAd__CustomLeaderboardAd-sc-18ls5m1-0 CoqsW mt6","mobileType":"mad","mediaTypes":["banner"],"bidders":true,"targeting":{},"scrollRefresh":false,"outOfPage":false,"visibilityOffset":300,"disableInitialHeight":false}' data-dimensions="728x90" id="ad">
#    </div>
#   </div>
#   <div class="Ad__Container-sc-1ah7c5n-0 eJdHEp RectToLeaderboardAd__CustomRectAd-sc-18ls5m1-1 koBxMZ mt6" spacing="6">
#    <div class="ad" data-ad-props='{"type":"rect","mobileType":"mrect","separator":"_","lazy":false,"spacing":6,"breakpoint":"extraLarge","dimensions":"300x250,300x600","className":"RectToLeaderboardAd__CustomRectAd-sc-18ls5m1-1 koBxMZ mt6","mobileDimensions":"300x250,320x50,300x50","mediaTypes":["banner"],"bidders":true,"targeting":{},"scrollRefresh":false,"outOfPage":false,"visibilityOffset":300,"insetSpacing":1,"autoRefresh":false,"disableInitialHeight":false}' data-dimensions="300x250,300x600" id="ad">
#    </div>
#   </div>
#  </div>
#  <div class="EducationAndExperience__CustomTruncatedContent-dbww3o-3 kxvSGL">
#   <span class="Span-sc-19wk4id-0 generic-toggler__Toggler-v0jryl-0 blHoZQ gzQShs EducationAndExperience__CustomToggler-dbww3o-1 XqWRJ" size="3" tabindex="0">
#    <h5 class="Heading__HeadingStyled-sc-1w5xk2o-0-h5 fuVjvo Heading-sc-1w5xk2o-1 EducationAndExperience__CustomHeading-dbww3o-2 cRrhAX fXoLCi" size="4" spacing="0">
#     Frequently Asked Questions About
#     <!-- -->
#     Dr. Duszak
#    </h5>
#    <svg class="Icon-sc-9wq8ul-0 generic-toggler__Chevron-v0jryl-1 hiHdJZ ldwRQL" height="1rem" role="img" width="1rem">
#     <use filter="0" xlink:href="#chevron">
#     </use>
#    </svg>
#   </span>
#   <div class="use-hidden-content__HiddenContent-sc-1i61n0d-0 kGUuPQ" spacing="0">
#    <div>
#     <div class="mb4" itemscope="" itemtype="https://schema.org/FAQPage">
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           Can I make an appointment online with
#           <!-- -->
#           Dr. Duszak
#           <!-- -->
#           ?
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <span itemprop="text">
#            Yes, you can
#            <a class="Anchor-byh49a-0 cVaFCm" href="/doctors/richard-duszak-130940" letter-spacing="0.6" prefix="\00ab\00a0">
#             book an appointment
#            </a>
#            with
#            <!-- -->
#            Dr. Duszak
#            <!-- -->
#            online today. It's simple, secure, and free.
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           Does
#           <!-- -->
#           Dr. Duszak
#           <!-- -->
#           offer telehealth?
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <span itemprop="text">
#            Call
#            <a class="Anchor-byh49a-0 cVaFCm" href="/doctors/richard-duszak-130940" letter-spacing="0.6" prefix="\00ab\00a0">
#             Dr. Duszak
#            </a>
#            for more information on telehealth services.
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           What do patients say about
#           <!-- -->
#           Dr. Duszak
#           <!-- -->
#           ?
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <span itemprop="text">
#            We’ve published patient experience ratings for
#            <!-- -->
#            Dr. Duszak
#            <!-- -->
#            in 6 key categories based on
#            <!-- -->
#            7
#            <!-- -->
#            reviews.
#            <a class="Anchor-byh49a-0 cVaFCm" href="/doctors/richard-duszak-130940#patient-experience" letter-spacing="0.6" prefix="\00ab\00a0">
#             <!-- -->
#             See ratings
#            </a>
#            .
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           Dr. Duszak
#           <!-- -->
#           accepts insurance
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <span itemprop="text">
#            Check
#            <!-- -->
#            Dr. Duszak's
#            <!-- -->
#            <a class="Anchor-byh49a-0 cVaFCm" href="#insurance" letter-spacing="0.6" prefix="\00ab\00a0">
#             profile
#            </a>
#            to see which insurance they accept.
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           Where is
#           <!-- -->
#           Dr. Duszak's
#           <!-- -->
#           office located?
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <div class="Raw-slyvem-0 ftTcof" color="#1A1D26" itemprop="text" size="4" spacing="0">
#            Dr. Duszak's  office is located at
#                                             5665 Peachtree Dunwoody Rd, Atlanta, GA.
#            <a href="#location">
#             View the map
#            </a>
#            .
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div itemprop="mainEntity" itemscope="" itemtype="https://schema.org/Question">
#       <div class="Bellow__BellowWrapper-sc-1wt7bw1-0 YideW" data-bellow="closed">
#        <button class="Bellow__HeadingButton-sc-1wt7bw1-1 imqZLc" data-bellow-toggle="true">
#         <h3 class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 demWpV Heading-sc-1w5xk2o-1 cRrhAX" size="3" spacing="0">
#          <span itemprop="name">
#           What are
#           <!-- -->
#           Dr. Duszak's
#           <!-- -->
#           areas of care?
#          </span>
#         </h3>
#         <svg class="Icon-sc-9wq8ul-0 hiHdJZ" height="1.5rem" role="img" width="1.5rem">
#          <use filter="0" xlink:href="#plus">
#          </use>
#         </svg>
#        </button>
#        <div class="Bellow__BellowBody-sc-1wt7bw1-2 kWzuAh" height="0">
#         <div class="Bellow__Content-sc-1wt7bw1-3 kGennU">
#          <div itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#           <div class="Raw-slyvem-0 ftTcof" color="#1A1D26" itemprop="text" size="4" spacing="0">
#            Radiologists use imaging to gather information about the structure and function of the human body that may be unavailable without surgery. They rely on penetrating radiation, such as X-rays, CT scans, and PET scans to diagnose diseases. They may also employ ultrasound and magnetic resonance imaging (MRI) scans. They also use various forms of radiation to kill cancerous tissues. For doctors who use radiology to treat cancers, see
#            <a href="https://health.usnews.com/doctors/radiation-oncologists">
#             radiation oncologists
#            </a>
#            .
#                                             See all conditions on Dr. Duszak's
#            <a href="/doctors/richard-duszak-130940">
#             profile
#            </a>
#            .
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </section>

# %%
# Find all HTML relating to Education & Experience (includes med school & residency, licenses, etc.)
ed_ex_elements = results.find_all("div", class_= "EducationAndExperience__Item-dbww3o-0 eUTnkN")

# Take a look at all the elements
for ed_ex_element in ed_ex_elements:
    print(ed_ex_element, end="\n"*2)
# Out:
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">University of Pennsylvania Health System</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Fellowship<span class="Span-sc-19wk4id-0 kukjnS" size="5">, <!-- -->Vascular and Interventional Radiology</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Duke University Hospital</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Residency<span class="Span-sc-19wk4id-0 kukjnS" size="5">, <!-- -->Radiology</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">York Hospital</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Internship<span class="Span-sc-19wk4id-0 kukjnS" size="5">, <!-- -->Transitional Year</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Pennsylvania State University College of Medicine</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Medical School</p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">NC State Medical License</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Active through <!-- -->1998</p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">PA State Medical License</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Active through <!-- -->2014</p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">MS State Medical License</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Active through <!-- -->2015</p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">TN State Medical License</p><p class="Paragraph-sc-1iyax29-0 kCHkVX" color="#515767" size="5" spacing="0">Active through <!-- -->2015</p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">SIR Fellow<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5"></span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Outstanding Faculty Mentor Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2015</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Most Influential Radiology Researcher<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2014</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Outstanding Reviewer Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2014</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Volunteer Service Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2014</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">William T. Thorwarth, Jr. Award for Excellence in Economics and Health Policy<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2013</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Best Doctors in Memphis<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2011</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Best Doctors in Memphis<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2012</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Featured Alumnus<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2010</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Fellow, Radiology Business Management Association<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2010</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Fellow (RBMA)<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2010</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Fellow, American College of Radiology<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2007</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Fellow (ACR)<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2007</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Exceptional Manuscript Reviewer Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2005</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Fellow, Society of Interventional Radiology<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2004</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Best Doctors in America<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2001</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Calhoun Award for Outstanding Contributions to Radiology Management<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2000</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Editor’s Recognition Award, with Special Distinction<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1999</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Editor’s Recognition Award, with Special Distinction<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 2000</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Distinguished Faculty Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1999</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Distinguished Reviewer Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1998</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Residents Annual Award for Excellence in Teaching<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1996</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Andrew E. Yeates Memorial Award for Excellence in Neuroradiology<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1993</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Sylvia and Gilbert Nurick Medical Achievement Award for Academic Excellence and Outstanding Contributions to the College Community<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1989</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">The Edward C. Hammond Memorial Scholarship for Academic Excellence<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1987</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Alpha Omega Alpha Honor Medical Society<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1987</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">Biology Department Outstanding Graduate Award<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1985</span></p></div>
#
# <div class="EducationAndExperience__Item-dbww3o-0 eUTnkN" spacing="4"><p class="Paragraph-sc-1iyax29-0 jyTtTz" size="5" spacing="0">University Scholarship<span class="Span-sc-19wk4id-0 gVDJqi" color="#515767" size="5">, 1981</span></p></div>

# %%
# using: https://realpython.com/beautiful-soup-web-scraper-python/

# Pick out the child element I'm interested in
for ed_ex_element in ed_ex_elements:
    organization_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 jyTtTz").text
    education_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 kCHkVX").text
    print(organization_element)
    print(education_element)
    print() # v-space between elements
# Out:
# University of Pennsylvania Health System
# Fellowship, Vascular and Interventional Radiology
#
# Duke University Hospital
# Residency, Radiology
#
# York Hospital
# Internship, Transitional Year
#
# Pennsylvania State University College of Medicine
# Medical School
#
# NC State Medical License
# Active through 1998
#
# PA State Medical License
# Active through 2014
#
# MS State Medical License
# Active through 2015
#
# TN State Medical License
# Active through 2015
#
# SIR Fellow
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-44abd7a387ba> in <module>
#       6     education_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 kCHkVX")
#       7     print(organization_element.text)
# ----> 8     print(education_element.text)
#       9     print() # v-space between elements
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Gather the radiologists' data
radiologist_name = "Richard Duszak"
# create a list to store the data
scraped_data = [] 
for ed_ex_element in ed_ex_elements:
    # initialize the dictionary
    radiologist_details = {}
    
    # parse out the exact text we want
    organization_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 jyTtTz").text
    education_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 kCHkVX").text
   
    # add data to the dictionary
    radiologist_details['radiologist_name'] = radiologist_name
    radiologist_details['organization_element'] = organization_element
    radiologist_details['education_element'] = education_element
    
    # append the scraped data to the list
    scraped_data.append(radiologist_details)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-7640a3946fd9> in <module>
#       8
#       9     organization_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 jyTtTz").text
# ---> 10     education_element = ed_ex_element.find("p", class_="Paragraph-sc-1iyax29-0 kCHkVX").text
#      11
#      12     # add data to the dictionary
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Create a data frame from the list of dictionaries and save as CSV
dataFrame = pd.DataFrame.from_dict(scraped_data)
dataFrame = to_csv('radiology_tainee_scraped_data.csv', index=False)

# View DF
dataFrame.head()
