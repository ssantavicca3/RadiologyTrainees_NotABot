# %%
# Scraping
from bs4 import BeautifulSoup
import requests

import json
import pandas as pd

import pprint

from urllib.request import Request, urlopen

from time import sleep
from random import randint

# %%
# Progress counter/tracker
from contextlib import contextmanager
from timeit import default_timer
import sys
from datetime import timedelta

# Define a timer w/ decoractor to use with the loop
@contextmanager
def elapsed_timer():
    start=default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start

# %% [markdown]
# # Testing w/ 2 radiologists

# %%
radiologists = ["Richard Duszak", "Andrew Rosenkrantz"]

# %%
prefix = 'https://www.doximity.com/pub/'
user_agent = {'User-agent' : 'Mozilla/5.0'}
input_name = radiologists[0].replace(' ', '-').lower()
degree = "-md"
url = prefix+input_name+degree
page = requests.get(url, headers=user_agent)
soup = BeautifulSoup(page.text, "html.parser")

#####################
full_name = soup.find("span", class_="user-full-name").text
first_name = soup.find("span", class_="user-name-first").text
last_name = soup.find("span", class_="user-name-last").text

specialty = soup.find("a", class_="profile-head-subtitle").text
city_state = soup.find("span", class_="profile-head-subtitle").text
subspecialty = soup.find("p", class_="user-subspecialty").text
job_title = soup.find("p", class_="user-job-title").text

st_address = soup.find("span", class_="black profile-contact-labels-wrap").text
PRE_phone_num = soup.find("div", class_="profile-contact-labels-wrap")
phone_num = PRE_phone_num.find("span", class_="black").text

ed_trn_elements = soup.find("ul", class_="profile-sectioned-list training").find_all("div", class_="profile-section-wrapper-text")
for element in ed_trn_elements:
    institution = element.find("span", class_="black").text
    education = element.find("span", class_="br").text
    print(institution)
    print(education)
    print()

########################
# print(full_name)
# print(first_name)
# print(last_name)
# print(specialty)
# print(city_state)
# print(subspecialty)
# print(job_title)
# print(st_address)
# print(phone_num)
# Out:
# University of Pennsylvania Health System
# Fellowship, Interventional Radiology - Independent, 1994 - 1995
#
# Duke University Hospital
# Residency, Radiology-Diagnostic, 1990 - 1994
#
# York Hospital
# Internship, Transitional Year, 1989 - 1990
#
# Pennsylvania State University College of Medicine
# Class of 1989
#
# La Salle University
# B.A., Biology, Maxima Cum Laude, General University Honors, 1981 - 1985
#
# [<div class="profile-section-wrapper-text"><span class="black" itemprop="name">University of Pennsylvania Health System</span><span class="br">Fellowship, Interventional Radiology - Independent, 1994 - 1995</span></div>, <div class="profile-section-wrapper-text"><span class="black" itemprop="name">Duke University Hospital</span><span class="br">Residency, Radiology-Diagnostic, 1990 - 1994</span></div>, <div class="profile-section-wrapper-text"><span class="black" itemprop="name">York Hospital</span><span class="br">Internship, Transitional Year, 1989 - 1990</span></div>, <div class="profile-section-wrapper-text"><span class="black" itemprop="name">Pennsylvania State University College of Medicine</span><span class="br">Class of 1989</span></div>, <div class="profile-section-wrapper-text"><span class="black" itemprop="name">La Salle University</span><span class="br">B.A., Biology, Maxima Cum Laude, General University Honors, 1981 - 1985</span></div>]

# %%
radiologists = ["Richard Duszak", "Andrew Rosenkrantz", "Nishant De Quadros"]
for rad in radiologists:
    print(rad.replace(' ', '-').lower())
# Out:
# richard-duszak
# andrew-rosenkrantz
# nishant-de-quadros

# %%
scraper_list = pd.read_csv(r"C:\Users\ssantavicca3\Documents\Work Files & Folders\RadiologyTrainees_NotABot\scraper_list.csv")
scraper_list.head()
for index, rad in scraper_list[0:5].iterrows():
    print(rad["first_nm"])
# Out:
# Justin
# 0
# Matthew
# 1
# Vincent
# 2
# Saba
# 3
# Daniel
# 4

# %%
# (scraper_list["first_nm"][0]+"-"+scraper_list["last_nm"][0]).lower()
# scraper_list[0:2].iat[0,0]
for index, rad in scraper_list[0:5].iterrows():
    npi = rad["NPI"]
    input_name = (rad["first_nm"]+" "+rad["last_nm"]).replace(' ', '-').lower()
#     input_name = rad.replace(' ', '-').lower()
    print(npi)
    print(input_name)
# Out:
# 1003002148
# justin-owens
# 1003002783
# matthew-hartman
# 1003002809
# vincent-graziano
# 1003006636
# saba-hasan
# 1003008517
# daniel-mendez

# %%
# Initialize request details and lists to dump data dicts
prefix = 'https://www.doximity.com/pub/'
user_agent = {'User-agent' : 'Mozilla/5.0'}
verif_data = []
ed_trn_data = []

# Loop through each radiologist and scrape data of interest
with elapsed_timer() as elapsed:
    n_iter = 0
    
    for index, rad in scraper_list.iterrows(): 
        npi = rad["NPI"]
        input_name = (rad["first_nm"]+" "+rad["last_nm"]).replace(' ', '-').lower()  # replace() covers two part last names (e.g., De Soto)
        
        # Beautiful Soup
        try:
            degree = "md"
            url = prefix+input_name+"-"+degree
            page = requests.get(url, headers=user_agent)
        except:
            # Account for DOs, or skip iteration if no hits at all
            try:
                degree = "do"
                url = prefix+input_name+"-"+degree
                page = requests.get(url, headers=user_agent)
            except:
                continue
                
        soup = BeautifulSoup(page.text, "html.parser")

        ## Verification data
        verif_details = {}
        verif_details['NPI'] = npi  #ID
        verif_details['url'] = url

        # Parse out exact text we want & add data to the dictionary
        try:
            verif_details['full_name'] = soup.find("span", class_="user-full-name").text
        except:
            pass

        try:
            verif_details['first_name'] = soup.find("span", class_="user-name-first").text
            verif_details['last_name'] = soup.find("span", class_="user-name-last").text
            verif_details['credentials'] = soup.find("span", class_="user-name-credentials").text
        except:
            pass
        
        try:
            verif_details['specialty'] = soup.find("a", class_="profile-head-subtitle").text
        except:
            pass

        try:
            city_state = soup.find("span", class_="profile-head-subtitle").text
            verif_details['city_state'] = city_state[2:]   #remove "/.n" from beginning of these strings
        except:
            pass

        try:
            verif_details['subspecialty'] = soup.find("p", class_="user-subspecialty").text
        except:
            pass

        try:
            verif_details['job_title'] = soup.find("p", class_="user-job-title").text
        except:
            pass

        try:
            verif_details['st_address'] = soup.find(itemprop="streetAddress").get("content")
            verif_details['zip'] = soup.find(itemprop="postalCode").get("content") 
            verif_details['st_address_full'] = soup.find("span", class_="black profile-contact-labels-wrap").text
        except:
            pass

        try:
            verif_details['phone_num'] = soup.find("div", class_="profile-contact-labels-wrap").find("span", class_="black").text
        except:
            pass
        
        # Append the dictionaries to the list
        verif_details['idx_scraper_list'] = index  
        verif_data.append(verif_details)

        ## Education and training data
        try:
            ed_trn_elements = soup.find("ul", class_="profile-sectioned-list training").find_all("div", class_="profile-section-wrapper-text")
            for element in ed_trn_elements:
                ed_trn_details = {}
                ed_trn_details['NPI'] = npi  #ID

                # Parse out exact text we want & add data to the dictionary
                try:
                    ed_trn_details['institution'] = element.find("span", class_="black").text
                except:
                    pass

                try:
                    ed_trn_details['education'] = element.find("span", class_="br").text
                except:
                    pass

                # Append the dictionaries to the list
                ed_trn_details['idx_scraper_list'] = index
                ed_trn_data.append(ed_trn_details)
        except:
            pass
        
        ## Counter and timer for progress checks  
        n_iter += 1
        if n_iter % 100 == 0:
            print("Iteration (radiologists): "+str(n_iter)+" ----- Time Elapsed: "+str(timedelta(seconds=round(elapsed()))))
            sys.stdout.flush()

            # Save intermediate output incase of crash or timeout
            filename1 = "datadump/doximity dump/saved_ed_trn_list.txt"
            with open(filename1, 'w') as f:
                for item in ed_trn_data:
                    f.write(f'{item}\n')
                    sys.stdout.flush()
            filename2 = "datadump/doximity dump/saved_verif_list.txt"
            with open(filename2, 'w') as f:
                for item in verif_data:
                    f.write(f'{item}\n')
                    sys.stdout.flush()

        # Iteration delay
        sleep(randint(1,2))
# Out:
# Iteration (radiologists): 100 ----- Time Elapsed: 0:02:48
# Iteration (radiologists): 200 ----- Time Elapsed: 0:05:25
# Iteration (radiologists): 300 ----- Time Elapsed: 0:08:12
# Iteration (radiologists): 400 ----- Time Elapsed: 0:10:52
# Iteration (radiologists): 500 ----- Time Elapsed: 0:13:49
# Iteration (radiologists): 600 ----- Time Elapsed: 0:16:31
# Iteration (radiologists): 700 ----- Time Elapsed: 0:19:11
# Iteration (radiologists): 800 ----- Time Elapsed: 0:21:47
# Iteration (radiologists): 900 ----- Time Elapsed: 0:24:36
# Iteration (radiologists): 1000 ----- Time Elapsed: 0:27:25
# Iteration (radiologists): 1100 ----- Time Elapsed: 0:30:14
# Iteration (radiologists): 1200 ----- Time Elapsed: 0:32:55

# %%
## Create and format a DF from the list of dictionaries
ed_trn_df = pd.DataFrame.from_dict(ed_trn_data)
verif_df = pd.DataFrame.from_dict(verif_data)

verif_df[0:50]
# Out:
#            NPI                                                url  \
# 0   1003002148       https://www.doximity.com/pub/justin-owens-md
# 1   1003002783    https://www.doximity.com/pub/matthew-hartman-md
# 2   1003002809   https://www.doximity.com/pub/vincent-graziano-md
# 3   1003006636         https://www.doximity.com/pub/saba-hasan-md
# 4   1003008517      https://www.doximity.com/pub/daniel-mendez-md
# 5   1003011933     https://www.doximity.com/pub/patrick-hurley-md
# 6   1003012444       https://www.doximity.com/pub/andrew-picel-md
# 7   1003013020         https://www.doximity.com/pub/norna-karp-md
# 8   1003013129      https://www.doximity.com/pub/david-sheehan-md
# 9   1003013830      https://www.doximity.com/pub/robert-burman-md
# 10  1003013848       https://www.doximity.com/pub/kevin-sawyer-md
# 11  1003014473       https://www.doximity.com/pub/rakesh-barak-md
# 12  1003015553    https://www.doximity.com/pub/michael-fishman-md
# 13  1003018276      https://www.doximity.com/pub/steven-reiman-md
# 14  1003018342         https://www.doximity.com/pub/brian-moon-md
# 15  1003018870      https://www.doximity.com/pub/garrett-colby-md
# 16  1003019654          https://www.doximity.com/pub/evan-sirc-md
# 17  1003021783        https://www.doximity.com/pub/john-texada-md
# 18  1003021791        https://www.doximity.com/pub/ankit-patel-md
# 19  1003024191     https://www.doximity.com/pub/srinivas-peddi-md
# 20  1003026212       https://www.doximity.com/pub/galon-morgan-md
# 21  1003026295     https://www.doximity.com/pub/jeremy-thacker-md
# 22  1003026329       https://www.doximity.com/pub/rishi-razdan-md
# 23  1003027285  https://www.doximity.com/pub/nishant-de quadro...
# 24  1003027376      https://www.doximity.com/pub/anthony-junck-md
# 25  1003027533      https://www.doximity.com/pub/kelly-roberts-md
# 26  1003027533      https://www.doximity.com/pub/kelly-starkey-md
# 27  1003029620    https://www.doximity.com/pub/alfred-shilling-md
# 28  1003034810      https://www.doximity.com/pub/jim-schwaiger-md
# 29  1003035353         https://www.doximity.com/pub/joel-stein-md
#
#                     full_name first_name  last_name                 specialty  \
# 0        JustinMichaelOwensMD     Justin      Owens                 Radiology
# 1   MatthewEdwardHartmanMDPhD    Matthew    Hartman                Cardiology
# 2     VincentAngeloGrazianoMD    Vincent   Graziano                Nephrology
# 3             SabaHasanMDFACP       Saba      Hasan         Internal Medicine
# 4             DanielLMendezMD     Daniel     Mendez   Physical Medicine/Rehab
# 5      PatrickMichaelHurleyMD    Patrick     Hurley                   Urology
# 6        AndrewCharlesPicelMD     Andrew      Picel  Interventional Radiology
# 7                 NornaKarpMD      Norna       Karp                 Radiology
# 8             DavidVSheehanMD      David    Sheehan                Psychiatry
# 9          RobertWardBurmanMD     Robert     Burman                 Radiology
# 10         KevinJamesSawyerMD      Kevin     Sawyer                 Radiology
# 11              RakeshBarakMD     Rakesh      Barak                 Radiology
# 12                        NaN        NaN        NaN                       NaN
# 13       StevenRobertReimanMD     Steven     Reiman                 Radiology
# 14               BrianWMoonMD      Brian       Moon            Anesthesiology
# 15             GarrettColbyMD    Garrett      Colby                 Radiology
# 16                EvanMSircMD       Evan       Sirc          Nuclear Medicine
# 17              JohnCTexadaMD       John     Texada                 Radiology
# 18              AnkitMPatelMD      Ankit      Patel      Otolaryngology (ENT)
# 19            SrinivasPeddiMD   Srinivas      Peddi                 Radiology
# 20          GalonCoryMorganMD      Galon     Morgan                 Radiology
# 21       JeremyWayneThackerMD     Jeremy    Thacker                 Radiology
# 22        RishiNormanRazdanMD      Rishi     Razdan                 Radiology
# 23                        NaN        NaN        NaN                       NaN
# 24        AnthonyDavidJunckMD    Anthony      Junck                 Radiology
# 25     KellyAnnRobertsMDFAAFP      Kelly    Roberts           Family Medicine
# 26                        NaN        NaN        NaN                       NaN
# 27     AlfredTannerShillingMD     Alfred   Shilling                 Radiology
# 28             JimSchwaigerMD        Jim  Schwaiger                 Radiology
# 29                JoelSteinMD       Joel      Stein   Physical Medicine/Rehab
#
#           city_state                                          job_title  \
# 0      Lafayette, LA                                        Physician\n
# 1        Seattle, WA                                        Physician\n
# 2          Wayne, NJ                                        Physician\n
# 3        Trenton, NJ  Director, Internal Medicine Residency Program,...
# 4      Liverpool, NY                                        Physician\n
# 5     Farmington, MI                                        Physician\n
# 6       Stanford, CA                                        Physician\n
# 7      Palo Alto, CA                                        Radiologist
# 8           Lutz, FL  Distinguished University Health Professor Emer...
# 9      Littleton, CO                                        Physician\n
# 10      Lakeland, FL                                        Physician\n
# 11       Reading, PA                                   Neuroradiologist
# 12               NaN                                                NaN
# 13         Plano, TX                                        Physician\n
# 14       Redding, CA                                        Physician\n
# 15    Birmingham, AL                                        Physician\n
# 16  Walnut Creek, CA                                        Physician\n
# 17     Knoxville, TN                                        Physician\n
# 18        Joliet, IL                                        Physician\n
# 19  Santa Monica, CA                        Tower Imaging Medical Group
# 20         Plano, TX                                        Physician\n
# 21     Lexington, KY  Assistant Professor, Radiology, University of ...
# 22  Jacksonville, FL                                   Medical Director
# 23               NaN                                                NaN
# 24     Pensacola, FL                                        radiologist
# 25       Bronson, FL                                        Physician\n
# 26               NaN                                                NaN
# 27       Roanoke, VA                                        Physician\n
# 28         Huron, SD                      Huron Regional Medical Center
# 29      New York, NY  Rehabilitation and Regenerative Medicine, Colu...
#
#                                            st_address    zip  \
# 0                                1214 Coolidge Street  70503
# 1                                550 17th Ave Ste 680  98122
# 2                          246 Hamburg Tpke Suite 207  07470
# 3                                    446 Bellevue Ave  08618
# 4                                      7449 Morgan Rd  13090
# 5                      32255 Northwestern Hwy Ste 105  48334
# 6    Stanford Radiology Dept 300 Pasteur Dr Rm H1330C  94305
# 7                              2581 Samaritan Dr. 100  94301
# 8                       611 Warren Rd, Lutz, FL 33548  33548
# 9                               10240 Park Meadows Dr  80124
# 10                           1305 Lakeland Hills Blvd  33805
# 11                                  2500 Bernville Rd  19605
# 12                                                NaN    NaN
# 13                         4708 Alliance Blvd Ste 150  75093
# 14                                  2175 Rosaline Ave  96001
# 15                               100 Pilot Medical Dr  35235
# 16                             1601 Ygnacio Valley Rd  94598
# 17                            2001 Laurel Ave Ste 502  37916
# 18                                 2201 Glenwood Ave.  60435
# 19                                 2202 Wilshire Blvd  90403
# 20                                     3901 W 15th St  75075
# 21                            800 Rose St Hx-302 Ukmc  40536
# 22                                      2416 Dunn Ave  32218
# 23                                                NaN    NaN
# 24                                     5151 N 9th Ave  32504
# 25                                      445 Ishie Ave  32621
# 26                                                NaN    NaN
# 27                                 1906 Belleview Ave  24014
# 28                                      111 4th St SE  57350
# 29  180 Fort Washington Avenue Harkness Pavilion R...  10032
#
#                                       st_address_full       phone_num  \
# 0             1214 Coolidge StreetLafayette, LA 70503  (337) 289-7991
# 1                550 17th AveSte 680Seattle, WA 98122  (206) 215-4545
# 2            246 Hamburg TpkeSuite 207Wayne, NJ 07470  (973) 653-3366
# 3                   446 Bellevue AveTrenton, NJ 08618  (609) 394-6031
# 4                   7449 Morgan RdLiverpool, NY 13090  (315) 451-5400
# 5   32255 Northwestern HwySte 105Farmington, MI 48334  (248) 406-1089
# 6   Stanford Radiology Dept300 Pasteur Dr Rm H1330...  (650) 723-8406
# 7            2581 Samaritan Dr.100Palo Alto, CA 94301  (503) 731-2900
# 8         611 Warren Rd, Lutz, FL 33548Lutz, FL 33548             NaN
# 9            10240 Park Meadows DrLittleton, CO 80124  (303) 471-7700
# 10         1305 Lakeland Hills BlvdLakeland, FL 33805  (863) 688-2334
# 11                 2500 Bernville RdReading, PA 19605  (610) 373-0165
# 12                                                NaN             NaN
# 13           4708 Alliance BlvdSte 150Plano, TX 75093  (972) 596-6800
# 14                 2175 Rosaline AveRedding, CA 96001             NaN
# 15           100 Pilot Medical DrBirmingham, AL 35235  (205) 871-4274
# 16       1601 Ygnacio Valley RdWalnut Creek, CA 94598  (925) 939-3000
# 17          2001 Laurel AveSte 502Knoxville, TN 37916  (865) 595-4100
# 18                 2201 Glenwood Ave.Joliet, IL 60435  (815) 725-1191
# 19           2202 Wilshire BlvdSanta Monica, CA 90403  (310) 264-9000
# 20                      3901 W 15th StPlano, TX 75075  (972) 596-6800
# 21          800 Rose StHx-302 UkmcLexington, KY 40536  (859) 257-4457
# 22                2416 Dunn AveJacksonville, FL 32218             NaN
# 23                                                NaN             NaN
# 24                  5151 N 9th AvePensacola, FL 32504  (850) 476-8602
# 25                     445 Ishie AveBronson, FL 32621  (352) 565-5990
# 26                                                NaN             NaN
# 27                1906 Belleview AveRoanoke, VA 24014             NaN
# 28                       111 4th St SEHuron, SD 57350  (605) 353-6209
# 29  180 Fort Washington AvenueHarkness Pavilion Ro...  (212) 305-4818
#
#     idx_scraper_list                                       subspecialty
# 0                  0                                                NaN
# 1                  1                                                NaN
# 2                  2                                                NaN
# 3                  3                                                NaN
# 4                  4      Pain Medicine, Sports Medicine (Non-Surgical)
# 5                  5                                                NaN
# 6                  6                                                NaN
# 7                  7                    Breast Imaging, Women's Imaging
# 8                  8                                                NaN
# 9                  9                                                NaN
# 10                10               Abdominal Imaging, Nuclear Radiology
# 11                11                  Neuroradiology, Nuclear Radiology
# 12                12                                                NaN
# 13                13                                                NaN
# 14                14                                                NaN
# 15                15                       Bone Imaging/Musculoskeletal
# 16                16                                                NaN
# 17                17                                                NaN
# 18                18                                                NaN
# 19                19       Bone Imaging/Musculoskeletal, Neuroradiology
# 20                20                                                NaN
# 21                21                                                NaN
# 22                22  Interventional Neuroradiology, Vascular & Inte...
# 23                23                                                NaN
# 24                24                                                NaN
# 25                25                                                NaN
# 26                26                                                NaN
# 27                27  Interventional Neuroradiology, Vascular & Inte...
# 28                28                                                NaN
# 29                29                                                NaN

# %% [markdown]
# # Just need to run loop on full list of radiologists.
#
# ## Before doing so, maybe run on first 25-50 rads to (1) get an estimate of ETA, and (2) determine whether there are any bugs that need to be accounted for before full run (e.g., maybe a try/except for MDs/DOs/no page at all).
#
# ## May also need to do a follow up scraper with google searches (e.g., "Michael Fishman MD doximity radiology") do get the profiles of people with either NaN or non-radiology specialties that likely shared name with multiple other physicians. Eg:
# https://www.doximity.com/pub/michael-fishman-md-ff5f620a
# https://www.doximity.com/pub/michael-fishman-md-acf558de
# https://www.doximity.com/pub/michael-fishman-md-8b21aefd
